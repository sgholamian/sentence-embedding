# %%
# %pip install sister

import sister
embedder = sister.MeanEmbedding(lang="en")

sentences = ["I like Dogs", "I like cats"]

for sentence in sentences:
    vector = embedder(sentence)
    print (vector)  # 300-dim vector
#vector = embedder(sentence)  # 300-dim vector

# %%
print("hello")
# Out:
# hello

# %%
#loading pretrained word2vec embedding 
# %%time
from sister.word_embedders import Word2VecEmbedding

#embedder = sister.Word2VecEmbedding(lang="en")

sentence_embedding = sister.MeanEmbedding(Word2VecEmbedding())

sentence = "I like Dogs"
vector = sentence_embedding(sentence)  # 300-dim vector
